# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.shape
# Out:
# (1000, 8)

# %%
# datatype
data.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# parental_level_of_education    object
# lunch                          object
# test_preparation_course        object
# math_score                      int64
# reading_score                   int64
# writing_score                   int64
# dtype: object

# %%
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# descriptive stats
data.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.describe(include="object")
# Out:
#         gender race_ethnicity parental_level_of_education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test_preparation_course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
# columns name
data.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# complete information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Now explain if there are some issues in data to be resolved or all is ok.

# %%
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### Fetch all the record of females from race_ethinicity Group B, and their parents has master's degree

# %%
data[(data.gender=="female") & (data.race_ethnicity=="group B") & (data.parental_level_of_education=="master's degree")]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 167  female        group B             master's degree  free/reduced
# 178  female        group B             master's degree  free/reduced
# 514  female        group B             master's degree  free/reduced
# 781  female        group B             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 2                      none          90             95             93
# 167               completed          58             76             78
# 178               completed          52             70             62
# 514               completed          77             97             94
# 781                    none          77             90             84

# %% [markdown]
# ### Student with lunch standard having score more than or equal to 90

# %%
data[(data.lunch=="standard") & (data.math_score>=90)]
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 2    female        group B             master's degree  standard
# 34     male        group E                some college  standard
# 104    male        group C                some college  standard
# 114  female        group E           bachelor's degree  standard
# 121    male        group B          associate's degree  standard
# 165  female        group C           bachelor's degree  standard
# 171    male        group E            some high school  standard
# 179  female        group D            some high school  standard
# 233    male        group E            some high school  standard
# 263  female        group E                 high school  standard
# 286    male        group E          associate's degree  standard
# 306    male        group E                some college  standard
# 333    male        group B          associate's degree  standard
# ...

# %% [markdown]
# ### Who are good in maths males or females

# %%
f = data[data.gender=='female']

# %%
f
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
f['math_score'].mean()
# Out:
# 63.633204633204635

# %%
m = data[data.gender=='male']

# %%
m['math_score'].mean()
# Out:
# 68.72821576763485

# %%
data.groupby("gender")['math_score'].agg(['mean', 'max', "min"])
# Out:
#              mean  max  min
# gender
# female  63.633205  100    0
# male    68.728216  100   27

# %% [markdown]
# ### Find out if the test preparation course has an impact or not on the students performance.

# %%
data[data.test_preparation_course=='completed'].describe()
# Out:
#        math_score  reading_score  writing_score
# count  358.000000     358.000000     358.000000
# mean    69.695531      73.893855      74.418994
# std     14.444699      13.638384      13.375335
# min     23.000000      37.000000      36.000000
# 25%     60.000000      65.000000      66.000000
# 50%     69.000000      75.000000      76.000000
# 75%     79.000000      84.000000      83.000000
# max    100.000000     100.000000     100.000000

# %%
data[data.test_preparation_course=='none'].describe()
# Out:
#        math_score  reading_score  writing_score
# count  642.000000     642.000000     642.000000
# mean    64.077882      66.534268      64.504673
# std     15.192376      14.463885      14.999661
# min      0.000000      17.000000      10.000000
# 25%     54.000000      57.000000      54.000000
# 50%     64.000000      67.000000      65.000000
# 75%     74.750000      76.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
data.groupby("test_preparation_course")[["math_score","reading_score","writing_score"]].agg('mean')
# Out:
#                          math_score  reading_score  writing_score
# test_preparation_course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# ### Parent level affect on total score

# %%
data['total'] = data.math_score + data.reading_score+ data.writing_score

# %%
data['total']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total, Length: 1000, dtype: int64

# %%
data[(data.parental_level_of_education=="master's degree") | (data.parental_level_of_education=="bachelors's degree") | (data.parental_level_of_education=="associate's degree")]['total'].mean()
# Out:
# 211.2455516014235

# %%
data[(data.parental_level_of_education == "some college") | (data.parental_level_of_education == "some high school") | (data.parental_level_of_education == "high school")]['total'].mean()
# Out:
# 197.15640599001665
