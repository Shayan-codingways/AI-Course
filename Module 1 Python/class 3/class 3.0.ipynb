# %% [markdown]
# # String : Data in inverted commas
# -string is class
# -string is immutable (non-changeable)
# we can use pre defined functionality

# %%
course = 'artificial intelligence'
print(type(course))
# Out:
# <class 'str'>

# %%
course.capitalize()
# Out:
# 'Artificial intelligence'

# %%
course.upper()
# Out:
# 'ARTIFICIAL INTELLIGENCE'

# %%
course.lower()
# Out:
# 'artificial intelligence'

# %%
course.title()
# Out:
# 'Artificial Intelligence'

# %%
course.count('e')
# Out:
# 3

# %%
course.count('en')
# Out:
# 1

# %%
course
# Out:
# 'artificial intelligence'

# %%
course # immutable just makes copy on functions
# course displays its original value.
# Out:
# 'artificial intelligence'

# %%
course.endswith('e')
# Out:
# True

# %%
course.startswith('a')
# Out:
# True

# %%
marks= '100'

# %%
marks.isalnum() 
# is alphanumeric (contains alphabets or numeric)
# Out:
# True

# %%
marks.isalpha()
# Out:
# False

# %%
marks.isprintable()
# Out:
# True

# %% [markdown]
# ![image.png](attachment:26b1cee5-be2e-46b2-b6b4-5a2813867ee3.png)

# %%
marks = "\n"
marks.isprintable()
# Out:
# False

# %% [markdown]
# # Conacatenation

# %%
first_name='Shayan'
second_name='Anwar'

# %%
first_name + " " + second_name
# Out:
# 'Shayan Anwar'

# %%
age=30

# %%
first_name + " " + second_name +  " " +str(age)  #integer age type won't permemnantly change
# Out:
# 'Shayan Anwar 30'

# %%
age=str(age)

# %%
type(age)
# Out:
# str

# %%
fname = input("name")
lname = input("name")
age= float(input("age: ")) # float used so that string if decimal can only be converted to float and not integer

#  f string --> formatted string as the string has placeholders. 
print(f"mr {fname} s/o {lname} is {age} years old") 

# format(placeholders)
print("mr {} s/o {} is {} years old".format(fname, lname,age))
# Out:
# name Shayan
# name Anwar
# age:  23
# mr Shayan s/o Anwar is 23.0 years old
# mr Shayan s/o Anwar is 23.0 years old

# %% [markdown]
# # string indexes and slicing

# %%
text = "it's your happy birthday"

# %%
# multi_line string
text = ''' jhffjjfjfnfjfjfkfkffgg
fgngjgjkgjzgkzjgzgkkzgkgt'''

# %%
text = 'Pakistan'

# index 012345..................

# %%
len(text)
# Out:
# 8

# %%
# [] square brackets are used for indexing 
text[0]
# Out:
# 'P'

# %%
for i in range(3,7):
   print(text[i])
# Out:
# i
# s
# t
# a

# %%
text[-1]  
# last indexed
# Out:
# 'n'

# %%
text[len(text)-1]
# Out:
# 'n'

# %%
# slicing 
text = "it's a promising focus for virtual"  # sub string

# %%
text[0:10] # 0--9  [start,end,step]
# returns a copy as the string is immutable
# Out:
# "it's a pro"

# %%
text[5:13]
# Out:
# 'a promks'

# %%
country='pakistan'

# %%
country[0:6:1]
# Out:
# 'pakist'

# %%
country[0:6:2]
# Out:
# 'pks'

# %%
# Excercise 1
print("pas", 7,3.4)

print("pas", 7,3.4, sep="-")
# Out:
# pas 7 3.4
# pas-7-3.4

# %%
# prints in separate lines as by default end="\n" in print command
print("pas")
print(4)
print(6.3)

# doesn't want it in separate lines. 
print("pas", end=" ")
print(4, end=" ")
print(6.3, end=" ")
# Out:
# pas
# 4
# 6.3
# pas 4 6.3

# %%
story="once upon a time there was a youtuber named harry. who uploaded python course with notes"



# function 3  string.find(word)   ****just for 1st occurence****
print(story.find('harry')) 
print(story.find('s')) 
print(story.find('ce')) 
print(story.find('Harry')) # not in string outputs -1
print(story.find('once')) 


# function 3  string.replace(word to replace, with what)
print(story.replace('harry','shayan')) 
print(story.replace('a','T'))  # replaces all alphabets words
# Out:
# 44
# 25
# 2
# -1
# 0
# once upon a time there was a youtuber named shayan. who uploaded python course with notes
# once upon T time there wTs T youtuber nTmed hTrry. who uploTded python course with notes

# %%
# escape sequences
story="once \t\tupon a \'time \"there\" was a \\youtuber named harry \nwho uploaded python course with notes"
print(story)
# Out:
# once 		upon a 'time "there" was a \youtuber named harry
# who uploaded python course with notes

# %% [markdown]
# # Python collections/Data Structures
# - Lists
# - Tuples
# - Disctionary
# - Set

# %% [markdown]
# # LIST
# - []
# - many values
# - mutable
# - index
# - slice
# - copy

# %%
a=[3,4,5,'dff']
a
# Out:
# [3, 4, 5, 'dff']

# %%
students = ['ALi','Basit','gghdh']
students
# Out:
# ['ALi', 'Basit', 'gghdh']

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
a[0]
# Out:
# 3

# %%
'''Lsit methods'''

# ..1 (list.sort) --> ascending order

l1=[1,8,7,2,21,15] 
# l1=l1.sort()  not a correct way to do.

l1.sort()
print(l1)


# ..2 (list.reverse) --> reverse order

l1=[1,8,7,2,21,15] 

l1.reverse()
print(l1)


# ..3 (list.append(object to append)) --> adds to the end

l1=[1,8,7,2,21,15] 

l1.append('***')  # add to the end of document
print(l1)

l1.append(56) 
print(l1)


# ..4 (list.insert(index,value)) --> inserts obeject at particular index

l1=[1,8,7,2,21,15] 

l1.insert(0,544)  # adds 544 to index 0
l1.insert(2,'544')  # adds 544 to index 2
print(l1)


# ..5 (list.pop(index no)) --> remove obeject from particular index as input

l1=[1,8,7,2,21,15] 

l1.pop(2)  # remover object of at index 2 (removes 7)
print(l1)


# ..6 (list.remove) --> removes obeject by having object as input

l1=[1,8,7,2,21,15] 

l1.remove(21)  # removes a number/object from list
print(l1)


# ..7 (list.count) --> counts a particular element

l1=[1,8,7,2,21,34,34,21,23,21,15] 

a=l1.count(21)  # counts
print(a)
# Out:
# [1, 2, 7, 8, 15, 21]
# [15, 21, 2, 7, 8, 1]
# [1, 8, 7, 2, 21, 15, '***']
# [1, 8, 7, 2, 21, 15, '***', 56]
# [544, 1, '544', 8, 7, 2, 21, 15]
# [1, 8, 2, 21, 15]
# [1, 8, 7, 2, 15]
# 3

# %%
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
